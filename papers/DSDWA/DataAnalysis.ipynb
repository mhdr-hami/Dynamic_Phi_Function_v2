# %% [markdown]
# ### The following Installs Requirements.

# %%
# %pip install numpy
# %pip install matplotlib
# %pip install scipy
# %pip install pandas

# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
import pandas as pd
import scipy.stats as st

# %%
fileName = 'tmp_results'
import random
l = []
k = []
with open("./results/"+fileName+".txt", "r") as f:
    for line in f:
        data = line.split()
        if(len(data)): ## To check for empy lines
            if data[0] == "Heuristic" and data[6] == "1" and data[8] == "1.50":
                print(int(data[10]), end=", ")
                # l.append(random.randint(10, int(data[10])//2))
                l.append(random.randint(10, int(data[10])-10))
print()
print("std::vector<int> hardcodedNumbers = {", end="")
for i in l:
    print(i, end=", ")
print("};")
# Out:
# 41, 43, 41, 42, 42, 36, 30, 32, 32, 43, 43, 35, 36, 41, 44, 24, 46, 43, 36, 36, 34, 41, 33, 34, 32, 40, 33, 36, 38, 35, 38, 43, 42, 36, 39, 36, 40, 41, 35, 36, 36, 30, 48, 32, 39, 35, 35, 39, 33, 39, 44, 38, 50, 40, 29, 29, 36, 37, 35, 48, 31, 43, 40, 31, 31, 41, 28, 31, 37, 30, 30, 38, 37, 46, 30, 41, 34, 41, 28, 43, 39, 40, 31, 37, 32, 35, 34, 43, 38, 36, 41, 37, 34, 45, 34, 35, 32, 34, 39, 38,
# std::vector<int> hardcodedNumbers = {23, 12, 25, 20, 31, 14, 14, 10, 13, 13, 14, 15, 23, 20, 21, 12, 13, 28, 23, 17, 14, 22, 12, 22, 12, 12, 12, 22, 28, 25, 15, 13, 27, 21, 10, 19, 20, 15, 21, 22, 15, 12, 36, 20, 15, 19, 23, 12, 12, 10, 12, 25, 22, 11, 14, 13, 12, 23, 15, 28, 12, 13, 17, 10, 11, 16, 11, 19, 21, 17, 11, 17, 14, 24, 16, 24, 15, 23, 13, 15, 28, 22, 20, 13, 11, 12, 21, 20, 19, 22, 16, 14, 15, 15, 21, 17, 22, 12, 27, 13, };

# %% [markdown]
# ### The following Code generates the average of usedH/usedG of the Data.

# %%
fileName = 'Policies_mazes32-results'
l = []
with open("./results/"+fileName+".txt", "r") as f:
    for line in f:
        data = line.split()
        if(len(data)): ## To check for empy lines
            if data[0] == "The":
                l.append(float(data[3]))
a = np.array(l)
print(np.mean(a))
# Out:
# 0.18691858278002693

# %% [markdown]
# ### The following Code Reads the Data.

# %%
##Experiment 5: Created the box plots. Each plot, y-axis:work and x-axis:algs, for one weight.
weight_to_int = {"1.50":0, "2.00":1, '3.00':2, '4.00':3, '5.00':4, '6.00':5, '7.00':6, '8.00':7, '9.00':8, '10.00':9}
int_to_alg = {0:'WA*', 1:'pwXD', 2:'pwXU', 3:'XDP', 4:'XUP', 5:'DSP'}
numPolicies = len(int_to_alg)
numWeights = len(weight_to_int)
fileName = 'STP_results'
Weights = {"1.50":[], "2.00":[], '3.00':[], '4.00':[], '5.00':[], '6.00':[], '7.00':[], '8.00':[], '9.00':[], '10.00':[]}
for w in Weights.values():
    for i in range(numPolicies):
        a = []
        w.append(a)

cnt = 0
with open("./results/"+fileName+".txt", "r") as f:
    numLines = len(f.readlines())
with open("./results/"+fileName+".txt", "r") as f:
    for line in f:
        data = line.split()
        if(len(data)): ## To check for empy lines
            if data[0] == "MAP" and (data[7] in list(weight_to_int.keys())) and (int(data[5]) in list(int_to_alg.keys())):
                Weights[data[7]][int(data[5])].append(int(data[9]))
            if data[0] == "STP" and (data[5] in list(weight_to_int.keys())) and (int(data[3]) in list(int_to_alg.keys())):
                Weights[data[5]][int(data[3])].append(int(data[7]))

        cnt += 1
        if cnt/numLines*100 % 10 == 0:
            print(cnt/numLines*100, '%')
print("Done Reading the Data..")
# Out:
# 10.0 %
# 20.0 %
# 30.0 %
# 40.0 %
# 50.0 %
# 60.0 %
# 70.0 %
# 80.0 %
# 90.0 %
# 100.0 %
# Done Reading the Data..

# %% [markdown]
# ### The following Code Creates Box Plots.
# one plot for each weight, each containing #policies boxes.

# %%
for w in range(len(Weights.values())):
    data = []
    for alg in list(Weights.values())[w]:
        data.append(np.array(alg))

    fig, ax = plt.subplots()

    bp = ax.boxplot(data, showfliers=False, notch=False, sym='o', vert=True, whis=(5,95))
    # bp = ax.boxplot(data, showfliers=False, notch=False, sym='+', vert=True, whis=1.5)
    ax.set_yscale('log')
    
    plt.setp(bp['boxes'], color='black')
    plt.setp(bp['whiskers'], color='black')
    plt.setp(bp['fliers'], color='red', marker='o')
    ax.yaxis.grid(True, linestyle='-', which='major', color='lightgrey', alpha=0.8)
    ax.set(
        axisbelow=True,  # Hide the grid behind plot objects
        title=fileName + ' Plot for Weight=' + list(Weights.keys())[w],
        xlabel='Policies',
        ylabel='work',
    )

    box_colors = ['darkkhaki', 'royalblue']
    num_boxes = len(data)
    medians = np.empty(num_boxes)
    for i in range(num_boxes):
        box = bp['boxes'][i]
        box_x = []
        box_y = []
        for j in range(5):
            box_x.append(box.get_xdata()[j])
            box_y.append(box.get_ydata()[j])
        box_coords = np.column_stack([box_x, box_y])
        # Alternate between Dark Khaki and Royal Blue
        ax.add_patch(Polygon(box_coords, facecolor=box_colors[i % 2]))
        # Now draw the median lines back over what we just filled in
        med = bp['medians'][i]
        median_x = []
        median_y = []
        for j in range(2):
            median_x.append(med.get_xdata()[j])
            median_y.append(med.get_ydata()[j])
            ax.plot(median_x, median_y, 'k')
        medians[i] = median_y[0]
        # Finally, overplot the sample averages, with horizontal alignment
        # in the center of each box
        ax.plot(np.average(med.get_xdata()), np.average(data[i]),
                color='r', marker='*', markeredgecolor='k')
        
    # Due to the Y-axis scale being different across samples, it can be
    # hard to compare differences in medians across the samples. Add upper
    # X-axis tick labels with the sample medians to aid in comparison
    # (just use two decimal places of precision)
    pos = np.arange(num_boxes) + 1
    upper_labels = [str(round(s, 2)) for s in medians]
    thickness = ['bold', 'semibold']
    for tick, label in zip(range(num_boxes), ax.get_xticklabels()):

        ax.text(pos[tick], .97, upper_labels[tick],
                transform=ax.get_xaxis_transform(), weight=thickness[1],
                horizontalalignment='center', size='x-small')

    y_pos = np.arange(len(int_to_alg.values())+1)
    labels = ['']
    labels += list(int_to_alg.values())
    plt.xticks(y_pos, labels)

    plt.show()
    print('Box information:')
    for alg in range(len(data)):
        median = np.median(data[alg])
        average = np.average(data[alg])

        upper_quartile = np.percentile(data[alg], 75)
        lower_quartile = np.percentile(data[alg], 25)

        iqr = upper_quartile - lower_quartile
        upper_whisker = data[alg][data[alg]<=upper_quartile+1.5*iqr].max()
        lower_whisker = data[alg][data[alg]>=lower_quartile-1.5*iqr].min()

        print(' Policy: '+int_to_alg[alg])
        print(' median: ', median)
        print(' average: ', round(average, 2))
        print(' upper_quartile: ', upper_quartile)
        print(' lower_quartile: ', lower_quartile)
        print(' upper_whisker: ', upper_whisker)
        print(' lower_whisker: ', lower_whisker)
        print()
    print('====================================')
# Out:
# Box information:
#  Policy: WA*
#  median:  116694.0
#  average:  320115.81
#  upper_quartile:  312157.5
#  lower_quartile:  30879.25
#  upper_whisker:  675746
#  lower_whisker:  654
#
#  Policy: pwXD
#  median:  31510.5
#  average:  70287.56
#  upper_quartile:  57801.5
#  lower_quartile:  17160.5
#  upper_whisker:  112771
#  lower_whisker:  1277
#
#  Policy: pwXU
#  median:  299135.5
#  average:  1094395.42
#  upper_quartile:  881672.5
#  lower_quartile:  104612.75
#  upper_whisker:  1829281
#  lower_whisker:  2532
#
#  Policy: XDP
#  median:  77303.5
#  average:  187216.21
#  upper_quartile:  183341.75
#  lower_quartile:  25571.5
#  upper_whisker:  417075
#  lower_whisker:  973
#
#  Policy: XUP
#  median:  152238.0
#  average:  468165.14
#  upper_quartile:  431706.0
#  lower_quartile:  44676.0
#  upper_whisker:  906028
#  lower_whisker:  1289
#
#  Policy: DSP
#  median:  31216.5
#  average:  57356.5
#  upper_quartile:  60115.5
#  lower_quartile:  15157.75
#  upper_whisker:  116789
#  lower_whisker:  459
#
# ====================================
# Box information:
#  Policy: WA*
#  median:  21420.5
#  average:  40635.43
#  upper_quartile:  44074.0
#  lower_quartile:  9905.75
#  upper_whisker:  91398
#  lower_whisker:  809
#
#  Policy: pwXD
#  median:  7538.5
#  average:  11226.78
#  upper_quartile:  15235.25
#  lower_quartile:  3408.25
#  upper_whisker:  31494
#  lower_whisker:  1107
#
#  Policy: pwXU
#  median:  73387.5
#  average:  431336.85
#  upper_quartile:  284832.5
#  lower_quartile:  25750.75
#  upper_whisker:  603984
#  lower_whisker:  1173
#
#  Policy: XDP
#  median:  12367.5
#  average:  21330.01
#  upper_quartile:  22692.25
#  lower_quartile:  3851.25
#  upper_whisker:  50275
#  lower_whisker:  454
#
#  Policy: XUP
#  median:  31249.0
#  average:  71710.68
#  upper_quartile:  85619.0
#  lower_quartile:  16505.25
#  upper_whisker:  167867
#  lower_whisker:  744
#
#  Policy: DSP
#  median:  6468.5
#  average:  11070.64
#  upper_quartile:  14591.5
#  lower_quartile:  3722.25
#  upper_whisker:  30623
#  lower_whisker:  1140
#
# ====================================
# Box information:
#  Policy: WA*
#  median:  5946.0
#  average:  11556.05
#  upper_quartile:  12524.5
#  lower_quartile:  3238.5
#  upper_whisker:  24644
#  lower_whisker:  546
#
#  Policy: pwXD
#  median:  3343.5
#  average:  4977.79
#  upper_quartile:  6580.0
#  lower_quartile:  1697.75
#  upper_whisker:  13545
#  lower_whisker:  401
#
#  Policy: pwXU
#  median:  21528.0
#  average:  81043.26
#  upper_quartile:  50549.0
#  lower_quartile:  10060.25
#  upper_whisker:  106938
#  lower_whisker:  887
#
#  Policy: XDP
#  median:  4769.5
#  average:  7441.61
#  upper_quartile:  8828.75
#  lower_quartile:  2221.75
#  upper_whisker:  16526
#  lower_whisker:  376
#
#  Policy: XUP
#  median:  7558.5
#  average:  16889.96
#  upper_quartile:  20811.5
#  lower_quartile:  3802.75
#  upper_whisker:  44334
#  lower_whisker:  709
#
#  Policy: DSP
#  median:  3088.0
#  average:  4858.12
#  upper_quartile:  6413.0
#  lower_quartile:  1492.5
#  upper_whisker:  13607
#  lower_whisker:  449
#
# ====================================
# Box information:
#  Policy: WA*
#  median:  3802.5
#  average:  6060.38
#  upper_quartile:  7569.5
#  lower_quartile:  1750.5
#  upper_whisker:  16236
#  lower_whisker:  372
#
#  Policy: pwXD
#  median:  3269.0
#  average:  4325.43
#  upper_quartile:  5629.0
#  lower_quartile:  2070.25
#  upper_whisker:  10149
#  lower_whisker:  438
#
#  Policy: pwXU
#  median:  10397.5
#  average:  24650.68
#  upper_quartile:  25051.0
#  lower_quartile:  5143.25
#  upper_whisker:  53104
#  lower_whisker:  960
#
#  Policy: XDP
#  median:  2898.0
#  average:  5003.18
#  upper_quartile:  5697.25
#  lower_quartile:  1530.75
#  upper_whisker:  11569
#  lower_whisker:  402
#
#  Policy: XUP
#  median:  5762.5
#  average:  9437.59
#  upper_quartile:  12459.75
#  lower_quartile:  3091.75
#  upper_whisker:  22556
#  lower_whisker:  430
#
#  Policy: DSP
#  median:  2105.0
#  average:  2912.85
#  upper_quartile:  4092.0
#  lower_quartile:  1181.75
#  upper_whisker:  8318
#  lower_whisker:  379
#
# ====================================
# Box information:
#  Policy: WA*
#  median:  3487.5
#  average:  4629.11
#  upper_quartile:  6012.75
#  lower_quartile:  2074.25
#  upper_whisker:  11635
#  lower_whisker:  635
#
#  Policy: pwXD
#  median:  3354.0
#  average:  4256.41
#  upper_quartile:  6388.0
#  lower_quartile:  1760.75
#  upper_whisker:  12330
#  lower_whisker:  382
#
#  Policy: pwXU
#  median:  8087.0
#  average:  13725.27
#  upper_quartile:  15532.25
#  lower_quartile:  3574.5
#  upper_whisker:  31538
#  lower_whisker:  442
#
#  Policy: XDP
#  median:  2671.5
#  average:  4438.89
#  upper_quartile:  5903.75
#  lower_quartile:  1458.5
#  upper_whisker:  11427
#  lower_whisker:  440
#
#  Policy: XUP
#  median:  4121.0
#  average:  6642.7
#  upper_quartile:  8047.5
#  lower_quartile:  1889.25
#  upper_whisker:  16447
#  lower_whisker:  545
#
#  Policy: DSP
#  median:  2309.5
#  average:  3353.0
#  upper_quartile:  4706.5
#  lower_quartile:  1164.25
#  upper_whisker:  8564
#  lower_whisker:  355
#
# ====================================
# Box information:
#  Policy: WA*
#  median:  3059.5
#  average:  4357.83
#  upper_quartile:  5588.25
#  lower_quartile:  1646.75
#  upper_whisker:  10467
#  lower_whisker:  400
#
#  Policy: pwXD
#  median:  3350.0
#  average:  4436.23
#  upper_quartile:  6367.5
#  lower_quartile:  2116.25
#  upper_whisker:  11974
#  lower_whisker:  391
#
#  Policy: pwXU
#  median:  4725.0
#  average:  13220.91
#  upper_quartile:  13689.5
#  lower_quartile:  2127.0
#  upper_whisker:  28727
#  lower_whisker:  433
#
#  Policy: XDP
#  median:  3139.0
#  average:  3610.7
#  upper_quartile:  4981.5
#  lower_quartile:  1420.25
#  upper_whisker:  9929
#  lower_whisker:  300
#
#  Policy: XUP
#  median:  3257.0
#  average:  5395.46
#  upper_quartile:  7609.5
#  lower_quartile:  1689.0
#  upper_whisker:  16454
#  lower_whisker:  436
#
#  Policy: DSP
#  median:  2425.5
#  average:  3246.79
#  upper_quartile:  4244.0
#  lower_quartile:  1292.25
#  upper_whisker:  8537
#  lower_whisker:  289
#
# ====================================
# Box information:
#  Policy: WA*
#  median:  3379.0
#  average:  3835.44
#  upper_quartile:  5363.5
#  lower_quartile:  1613.0
#  upper_whisker:  9914
#  lower_whisker:  423
#
#  Policy: pwXD
#  median:  3744.5
#  average:  4375.62
#  upper_quartile:  5881.25
#  lower_quartile:  2138.5
#  upper_whisker:  10559
#  lower_whisker:  402
#
#  Policy: pwXU
#  median:  4607.5
#  average:  7634.71
#  upper_quartile:  8477.25
#  lower_quartile:  1844.5
#  upper_whisker:  17435
#  lower_whisker:  378
#
#  Policy: XDP
#  median:  2873.0
#  average:  3644.06
#  upper_quartile:  4642.5
#  lower_quartile:  1437.25
#  upper_whisker:  9251
#  lower_whisker:  422
#
#  Policy: XUP
#  median:  3980.0
#  average:  4989.56
#  upper_quartile:  6540.75
#  lower_quartile:  1928.5
#  upper_whisker:  13429
#  lower_whisker:  412
#
#  Policy: DSP
#  median:  2469.5
#  average:  3191.76
#  upper_quartile:  4281.0
#  lower_quartile:  1237.0
#  upper_whisker:  8666
#  lower_whisker:  406
#
# ====================================
# Box information:
#  Policy: WA*
#  median:  2920.5
#  average:  3494.04
#  upper_quartile:  4751.5
#  lower_quartile:  1595.0
#  upper_whisker:  9404
#  lower_whisker:  423
#
#  Policy: pwXD
#  median:  3662.5
#  average:  4413.42
#  upper_quartile:  5795.0
#  lower_quartile:  2205.0
#  upper_whisker:  11119
#  lower_whisker:  407
#
#  Policy: pwXU
#  median:  4090.0
#  average:  5154.72
#  upper_quartile:  7022.5
#  lower_quartile:  1634.75
#  upper_whisker:  13838
#  lower_whisker:  419
#
#  Policy: XDP
#  median:  2740.5
#  average:  3598.58
#  upper_quartile:  4531.0
#  lower_quartile:  1411.5
#  upper_whisker:  8509
#  lower_whisker:  412
#
#  Policy: XUP
#  median:  3091.5
#  average:  4335.64
#  upper_quartile:  5393.75
#  lower_quartile:  1914.75
#  upper_whisker:  10055
#  lower_whisker:  400
#
#  Policy: DSP
#  median:  2759.5
#  average:  3348.38
#  upper_quartile:  4498.0
#  lower_quartile:  1525.0
#  upper_whisker:  8486
#  lower_whisker:  394
#
# ====================================
# Box information:
#  Policy: WA*
#  median:  3250.5
#  average:  4170.23
#  upper_quartile:  5310.25
#  lower_quartile:  1738.0
#  upper_whisker:  10416
#  lower_whisker:  412
#
#  Policy: pwXD
#  median:  3855.0
#  average:  4287.5
#  upper_quartile:  5596.0
#  lower_quartile:  2055.25
#  upper_whisker:  10659
#  lower_whisker:  407
#
#  Policy: pwXU
#  median:  3268.5
#  average:  4224.88
#  upper_quartile:  5569.25
#  lower_quartile:  1832.25
#  upper_whisker:  10620
#  lower_whisker:  394
#
#  Policy: XDP
#  median:  3043.0
#  average:  3688.53
#  upper_quartile:  4817.75
#  lower_quartile:  1828.75
#  upper_whisker:  8475
#  lower_whisker:  356
#
#  Policy: XUP
#  median:  3063.5
#  average:  3816.71
#  upper_quartile:  4736.75
#  lower_quartile:  1744.75
#  upper_whisker:  8886
#  lower_whisker:  412
#
#  Policy: DSP
#  median:  2968.5
#  average:  3431.83
#  upper_quartile:  4544.5
#  lower_quartile:  1588.25
#  upper_whisker:  8942
#  lower_whisker:  467
#
# ====================================
# Box information:
#  Policy: WA*
#  median:  3187.0
#  average:  3757.9
#  upper_quartile:  4636.0
#  lower_quartile:  1742.25
#  upper_whisker:  8688
#  lower_whisker:  412
#
#  Policy: pwXD
#  median:  4204.5
#  average:  4620.91
#  upper_quartile:  6082.25
#  lower_quartile:  2394.25
#  upper_whisker:  11095
#  lower_whisker:  407
#
#  Policy: pwXU
#  median:  3197.5
#  average:  3581.89
#  upper_quartile:  5303.25
#  lower_quartile:  1780.25
#  upper_whisker:  9062
#  lower_whisker:  418
#
#  Policy: XDP
#  median:  3004.0
#  average:  3581.23
#  upper_quartile:  4566.5
#  lower_quartile:  1945.25
#  upper_whisker:  7472
#  lower_whisker:  481
#
#  Policy: XUP
#  median:  2920.0
#  average:  3858.76
#  upper_quartile:  4350.25
#  lower_quartile:  1662.75
#  upper_whisker:  8064
#  lower_whisker:  406
#
#  Policy: DSP
#  median:  2961.5
#  average:  3285.61
#  upper_quartile:  4775.25
#  lower_quartile:  1786.0
#  upper_whisker:  7758
#  lower_whisker:  507
#
# ====================================

# %% [markdown]
# ### The following Code Creates Violin Plots.
# one plot for each weight, each containing #policies violins.

# %%
for w in range(len(Weights.values())):
    data = []
    for alg in list(Weights.values())[w]:
        data.append(np.array(alg))
    fig, axs = plt.subplots()

    axs.yaxis.grid(True, linestyle='-', which='major', color='lightgrey', alpha=0.8)
    axs.set(
        axisbelow=True,  # Hide the grid behind plot objects
        title=fileName + ' Plot for Weight=' + list(Weights.keys())[w],
        xlabel='Policies',
        ylabel='work',
    )
        
    # Due to the Y-axis scale being different across samples, it can be
    # hard to compare differences in medians across the samples. Add upper
    # X-axis tick labels with the sample medians to aid in comparison
    # (just use two decimal places of precision)
    medians = [np.median(data[alg]) for alg in range(len(data))]
    num_violins = len(data)
    pos = np.arange(num_violins) + 1
    upper_labels = [str(round(s, 2)) for s in medians]
    thickness = ['bold', 'semibold']
    for tick, label in zip(range(num_violins), axs.get_xticklabels()):

        axs.text(pos[tick], .97, upper_labels[tick],
                transform=axs.get_xaxis_transform(), weight=thickness[1],
                horizontalalignment='center', size='x-small')

    y_pos = np.arange(len(int_to_alg.values())+1)
    labels = ['']
    labels += list(int_to_alg.values())
    plt.xticks(y_pos, labels)
    

    # plot violin plot
    axs.violinplot(data, showmeans=False, showmedians=True)

    plt.show()
    print('Box information:')
    for alg in range(len(data)):
        median = np.median(data[alg])
        average = np.average(data[alg])

        print(' Policy: '+int_to_alg[alg])
        print(' median: ', median)
        print(' average: ', round(average, 2))
        print()
    print('====================================')
# Out:
# Box information:
#  Policy: WA*
#  median:  115746.0
#  average:  114023.67
#
#  Policy: pwXD
#  median:  106753.0
#  average:  108103.99
#
#  Policy: pwXU
#  median:  126381.0
#  average:  120868.48
#
#  Policy: XDP
#  median:  110592.0
#  average:  110570.01
#
#  Policy: XUP
#  median:  121359.0
#  average:  117972.89
#
#  Policy: DSP
#  median:  117038.0
#  average:  115042.67
#
# ====================================
# Box information:
#  Policy: WA*
#  median:  105659.0
#  average:  106831.2
#
#  Policy: pwXD
#  median:  99001.0
#  average:  99687.21
#
#  Policy: pwXU
#  median:  117353.0
#  average:  115518.59
#
#  Policy: XDP
#  median:  102772.0
#  average:  103136.84
#
#  Policy: XUP
#  median:  109736.0
#  average:  111076.62
#
#  Policy: DSP
#  median:  106202.0
#  average:  106930.74
#
# ====================================
# Box information:
#  Policy: WA*
#  median:  96269.0
#  average:  97434.64
#
#  Policy: pwXD
#  median:  91668.0
#  average:  93288.19
#
#  Policy: pwXU
#  median:  99226.0
#  average:  104269.19
#
#  Policy: XDP
#  median:  95140.0
#  average:  95836.31
#
#  Policy: XUP
#  median:  95878.0
#  average:  99209.87
#
#  Policy: DSP
#  median:  96458.0
#  average:  97735.3
#
# ====================================
# Box information:
#  Policy: WA*
#  median:  90805.0
#  average:  93102.05
#
#  Policy: pwXD
#  median:  88575.0
#  average:  90365.38
#
#  Policy: pwXU
#  median:  88491.0
#  average:  95242.84
#
#  Policy: XDP
#  median:  91227.0
#  average:  92352.68
#
#  Policy: XUP
#  median:  87139.0
#  average:  92034.65
#
#  Policy: DSP
#  median:  91787.0
#  average:  93568.82
#
# ====================================
# Box information:
#  Policy: WA*
#  median:  86432.0
#  average:  90005.73
#
#  Policy: pwXD
#  median:  86807.0
#  average:  88694.81
#
#  Policy: pwXU
#  median:  82955.0
#  average:  89556.91
#
#  Policy: XDP
#  median:  88604.0
#  average:  90221.64
#
#  Policy: XUP
#  median:  82202.0
#  average:  88100.5
#
#  Policy: DSP
#  median:  89119.0
#  average:  91240.11
#
# ====================================
# Box information:
#  Policy: WA*
#  median:  83284.0
#  average:  87827.9
#
#  Policy: pwXD
#  median:  85649.0
#  average:  87624.92
#
#  Policy: pwXU
#  median:  79674.0
#  average:  86239.34
#
#  Policy: XDP
#  median:  86583.0
#  average:  88823.09
#
#  Policy: XUP
#  median:  79450.0
#  average:  85543.72
#
#  Policy: DSP
#  median:  87449.0
#  average:  89740.65
#
# ====================================
# Box information:
#  Policy: WA*
#  median:  81433.0
#  average:  86466.21
#
#  Policy: pwXD
#  median:  84797.0
#  average:  86903.64
#
#  Policy: pwXU
#  median:  77838.0
#  average:  84129.45
#
#  Policy: XDP
#  median:  84705.0
#  average:  87738.93
#
#  Policy: XUP
#  median:  77818.0
#  average:  83791.59
#
#  Policy: DSP
#  median:  86051.0
#  average:  88721.47
#
# ====================================
# Box information:
#  Policy: WA*
#  median:  79936.0
#  average:  85272.36
#
#  Policy: pwXD
#  median:  84049.0
#  average:  86381.69
#
#  Policy: pwXU
#  median:  76516.0
#  average:  82769.17
#
#  Policy: XDP
#  median:  83553.0
#  average:  86922.36
#
#  Policy: XUP
#  median:  76733.0
#  average:  82546.79
#
#  Policy: DSP
#  median:  84768.0
#  average:  87938.69
#
# ====================================
# Box information:
#  Policy: WA*
#  median:  78858.0
#  average:  84293.42
#
#  Policy: pwXD
#  median:  83555.0
#  average:  85975.87
#
#  Policy: pwXU
#  median:  75642.0
#  average:  81784.9
#
#  Policy: XDP
#  median:  82567.0
#  average:  86254.48
#
#  Policy: XUP
#  median:  75865.0
#  average:  81676.84
#
#  Policy: DSP
#  median:  83681.0
#  average:  87323.42
#
# ====================================
# Box information:
#  Policy: WA*
#  median:  77871.0
#  average:  83475.69
#
#  Policy: pwXD
#  median:  83183.0
#  average:  85645.33
#
#  Policy: pwXU
#  median:  74911.0
#  average:  81049.08
#
#  Policy: XDP
#  median:  81738.0
#  average:  85701.89
#
#  Policy: XUP
#  median:  75182.0
#  average:  81027.5
#
#  Policy: DSP
#  median:  83087.0
#  average:  86823.19
#
# ====================================

# %% [markdown]
# ### The following Code Creates the Ranking Rating.
# Gets the two policies you want to compare.
#
# Returns the the percentage of all problems in data, that one is better than the other.
#
# Enter 'end' to terminate the run.

# %%
from IPython.display import clear_output

table = []
for w in range(len(Weights.values())):
    data = []
    for alg in list(Weights.values())[w]:
        data.append(np.array(alg))
    table.append(data)

while True:
    print('Policies: ', int_to_alg, sep='')
    print('weights: ', list(weight_to_int.keys()), sep='')
    print('---------------------------------------------------------')

    # cl_w = input('Enter weight: ')
    # if str(cl_w).lower()=='end': break
    cl_p1 = input('Enter one policy (end to terminate): ')
    if str(cl_p1).lower()=='end': break
    cl_p2 = input('Enter another policy (end to terminate): ')
    if str(cl_p2).lower()=='end': break
    cl_p1 = int(cl_p1)
    cl_p2 = int(cl_p2)

    for cl_w in Weights.keys():

        listComparisonG = table[weight_to_int[cl_w]][cl_p1] > table[weight_to_int[cl_w]][cl_p2]
        listComparisonL = table[weight_to_int[cl_w]][cl_p1] < table[weight_to_int[cl_w]][cl_p2]
        listComparisonE = table[weight_to_int[cl_w]][cl_p1] == table[weight_to_int[cl_w]][cl_p2]
        comparisonG = np.sum(np.array(listComparisonG))
        comparisonL = np.sum(np.array(listComparisonL))
        comparisonE = np.sum(np.array(listComparisonE))

        sum = comparisonG + comparisonL + comparisonE

        print('---------------------- weight='+str(cl_w)+' ----------------------')
        print('In ',comparisonL,' out of ',sum,' (',round(comparisonL/sum*100, 2),' %) ',int_to_alg[cl_p1],' is better than ',int_to_alg[cl_p2],'.', sep='')
        print('In ',comparisonG,' out of ',sum,' (',round(comparisonG/sum*100, 2),' %) ',int_to_alg[cl_p1],' is worse than ',int_to_alg[cl_p2],'.', sep='')
        print('In ',comparisonE,' out of ',sum,' (',round(comparisonE/sum*100, 2),' %) ',' they have the same performance.', sep='')

    tmp = input('Press Enter (to continue) | end (to terminate):')
    if str(tmp).lower()=='end': break
    clear_output(wait=True)
# Out:
# Policies: {0: 'WA*', 1: 'pwXD', 2: 'pwXU', 3: 'XDP', 4: 'XUP', 5: 'DSP'}
# weights: ['1.50', '2.00', '3.00', '4.00', '5.00', '6.00', '7.00', '8.00', '9.00', '10.00']
# ---------------------------------------------------------
# ---------------------- weight=1.50 ----------------------
# In 81 out of 100 (81.0 %) DSP is better than XDP.
# In 19 out of 100 (19.0 %) DSP is worse than XDP.
# In 0 out of 100 (0.0 %)  they have the same performance.
# ---------------------- weight=2.00 ----------------------
# In 67 out of 100 (67.0 %) DSP is better than XDP.
# In 33 out of 100 (33.0 %) DSP is worse than XDP.
# In 0 out of 100 (0.0 %)  they have the same performance.
# ---------------------- weight=3.00 ----------------------
# In 62 out of 100 (62.0 %) DSP is better than XDP.
# In 38 out of 100 (38.0 %) DSP is worse than XDP.
# In 0 out of 100 (0.0 %)  they have the same performance.
# ---------------------- weight=4.00 ----------------------
# In 60 out of 100 (60.0 %) DSP is better than XDP.
# In 40 out of 100 (40.0 %) DSP is worse than XDP.
# In 0 out of 100 (0.0 %)  they have the same performance.
# ---------------------- weight=5.00 ----------------------
# In 55 out of 100 (55.0 %) DSP is better than XDP.
# In 45 out of 100 (45.0 %) DSP is worse than XDP.
# In 0 out of 100 (0.0 %)  they have the same performance.
# ---------------------- weight=6.00 ----------------------
# In 51 out of 100 (51.0 %) DSP is better than XDP.
# In 49 out of 100 (49.0 %) DSP is worse than XDP.
# In 0 out of 100 (0.0 %)  they have the same performance.
# ---------------------- weight=7.00 ----------------------
# In 54 out of 100 (54.0 %) DSP is better than XDP.
# In 46 out of 100 (46.0 %) DSP is worse than XDP.
# In 0 out of 100 (0.0 %)  they have the same performance.
# ---------------------- weight=8.00 ----------------------
# In 52 out of 100 (52.0 %) DSP is better than XDP.
# In 48 out of 100 (48.0 %) DSP is worse than XDP.
# In 0 out of 100 (0.0 %)  they have the same performance.
# ---------------------- weight=9.00 ----------------------
# In 55 out of 100 (55.0 %) DSP is better than XDP.
# In 45 out of 100 (45.0 %) DSP is worse than XDP.
# In 0 out of 100 (0.0 %)  they have the same performance.
# ---------------------- weight=10.00 ----------------------
# In 49 out of 100 (49.0 %) DSP is better than XDP.
# In 51 out of 100 (51.0 %) DSP is worse than XDP.
# In 0 out of 100 (0.0 %)  they have the same performance.

# %% [markdown]
# ### The following Code Provides Statistic's Info.
# It returns Mean, Median, and Confidence Interval.

# %%
for w in (Weights.keys()):
    print('---------------------- weight='+str(w)+' ----------------------')
    data_dict = {}
    data_dict['category'] = list(int_to_alg.values())
    data_dict['lower'] = []
    data_dict['upper'] = []
    for alg in range(len(Weights[w])):
        print(int_to_alg[alg], ': ',end=' ')
        data = np.array(Weights[w][alg])
        # print(data.shape)
        # print(data)

        ## Assuming Norm Distribution
        l, u = st.norm.interval(confidence=0.95, loc=np.mean(data), scale=st.sem(data))
        ## OR ##
        ## NOT Assuming a Distribution, Using Bootstrap
        # data = (data,)
        # res = st.bootstrap(data, np.mean, n_resamples=1000,confidence_level=0.95)
        # l = res.confidence_interval.low
        # u = res.confidence_interval.high

        m = np.mean(data)

        print('mean:', round(m, 2), '| lower bound:', round(l, 2), '| upper bound:',round(u, 2))
        data_dict['lower'].append(l)
        data_dict['upper'].append(u)
    
    dataset = pd.DataFrame(data_dict)
    for lower,upper,y in zip(dataset['lower'],dataset['upper'],range(len(dataset))):
        plt.plot((lower,upper),(y,y),'ro-')
    plt.yticks(range(len(dataset)),list(dataset['category']))
    plt.grid(True)
    plt.xscale('log')
    plt.show()
# Out:
# ---------------------- weight=1.50 ----------------------
# WA* :  mean: 320115.81 | lower bound: 198244.24 | upper bound: 441987.38
# pwXD :  mean: 70287.56 | lower bound: 40362.8 | upper bound: 100212.32
# pwXU :  mean: 1094395.42 | lower bound: 693332.02 | upper bound: 1495458.82
# XDP :  mean: 187216.21 | lower bound: 123601.3 | upper bound: 250831.12
# XUP :  mean: 468165.14 | lower bound: 247733.23 | upper bound: 688597.05
# DSP :  mean: 57356.5 | lower bound: 38166.8 | upper bound: 76546.2
# ---------------------- weight=2.00 ----------------------
# WA* :  mean: 40635.43 | lower bound: 28765.06 | upper bound: 52505.8
# pwXD :  mean: 11226.78 | lower bound: 8787.95 | upper bound: 13665.61
# pwXU :  mean: 431336.85 | lower bound: 234633.22 | upper bound: 628040.48
# XDP :  mean: 21330.01 | lower bound: 15795.06 | upper bound: 26864.96
# XUP :  mean: 71710.68 | lower bound: 53838.25 | upper bound: 89583.11
# DSP :  mean: 11070.64 | lower bound: 8731.38 | upper bound: 13409.9
# ---------------------- weight=3.00 ----------------------
# WA* :  mean: 11556.05 | lower bound: 7925.71 | upper bound: 15186.39
# pwXD :  mean: 4977.79 | lower bound: 4014.43 | upper bound: 5941.15
# pwXU :  mean: 81043.26 | lower bound: 6863.35 | upper bound: 155223.17
# XDP :  mean: 7441.61 | lower bound: 5751.05 | upper bound: 9132.17
# XUP :  mean: 16889.96 | lower bound: 12126.46 | upper bound: 21653.46
# DSP :  mean: 4858.12 | lower bound: 3822.65 | upper bound: 5893.59
# ---------------------- weight=4.00 ----------------------
# WA* :  mean: 6060.38 | lower bound: 4705.69 | upper bound: 7415.07
# pwXD :  mean: 4325.43 | lower bound: 3649.21 | upper bound: 5001.65
# pwXU :  mean: 24650.68 | lower bound: 17401.01 | upper bound: 31900.35
# XDP :  mean: 5003.18 | lower bound: 3808.4 | upper bound: 6197.96
# XUP :  mean: 9437.59 | lower bound: 7423.37 | upper bound: 11451.81
# DSP :  mean: 2912.85 | lower bound: 2466.04 | upper bound: 3359.66
# ---------------------- weight=5.00 ----------------------
# WA* :  mean: 4629.11 | lower bound: 3757.48 | upper bound: 5500.74
# pwXD :  mean: 4256.41 | lower bound: 3645.05 | upper bound: 4867.77
# pwXU :  mean: 13725.27 | lower bound: 10493.75 | upper bound: 16956.79
# XDP :  mean: 4438.89 | lower bound: 3485.41 | upper bound: 5392.37
# XUP :  mean: 6642.7 | lower bound: 5252.57 | upper bound: 8032.83
# DSP :  mean: 3353.0 | lower bound: 2755.72 | upper bound: 3950.28
# ---------------------- weight=6.00 ----------------------
# WA* :  mean: 4357.83 | lower bound: 3495.11 | upper bound: 5220.55
# pwXD :  mean: 4436.23 | lower bound: 3813.88 | upper bound: 5058.58
# pwXU :  mean: 13220.91 | lower bound: 8939.87 | upper bound: 17501.95
# XDP :  mean: 3610.7 | lower bound: 3062.96 | upper bound: 4158.44
# XUP :  mean: 5395.46 | lower bound: 4337.66 | upper bound: 6453.26
# DSP :  mean: 3246.79 | lower bound: 2721.26 | upper bound: 3772.32
# ---------------------- weight=7.00 ----------------------
# WA* :  mean: 3835.44 | lower bound: 3302.88 | upper bound: 4368.0
# pwXD :  mean: 4375.62 | lower bound: 3785.97 | upper bound: 4965.27
# pwXU :  mean: 7634.71 | lower bound: 5643.97 | upper bound: 9625.45
# XDP :  mean: 3644.06 | lower bound: 3042.65 | upper bound: 4245.47
# XUP :  mean: 4989.56 | lower bound: 4142.12 | upper bound: 5837.0
# DSP :  mean: 3191.76 | lower bound: 2719.29 | upper bound: 3664.23
# ---------------------- weight=8.00 ----------------------
# WA* :  mean: 3494.04 | lower bound: 2985.35 | upper bound: 4002.73
# pwXD :  mean: 4413.42 | lower bound: 3818.89 | upper bound: 5007.95
# pwXU :  mean: 5154.72 | lower bound: 4273.93 | upper bound: 6035.51
# XDP :  mean: 3598.58 | lower bound: 3005.32 | upper bound: 4191.84
# XUP :  mean: 4335.64 | lower bound: 3512.5 | upper bound: 5158.78
# DSP :  mean: 3348.38 | lower bound: 2881.53 | upper bound: 3815.23
# ---------------------- weight=9.00 ----------------------
# WA* :  mean: 4170.23 | lower bound: 3457.89 | upper bound: 4882.57
# pwXD :  mean: 4287.5 | lower bound: 3689.37 | upper bound: 4885.63
# pwXU :  mean: 4224.88 | lower bound: 3530.98 | upper bound: 4918.78
# XDP :  mean: 3688.53 | lower bound: 3166.94 | upper bound: 4210.12
# XUP :  mean: 3816.71 | lower bound: 3211.29 | upper bound: 4422.13
# DSP :  mean: 3431.83 | lower bound: 2952.24 | upper bound: 3911.42
# ---------------------- weight=10.00 ----------------------
# WA* :  mean: 3757.9 | lower bound: 3161.87 | upper bound: 4353.93
# pwXD :  mean: 4620.91 | lower bound: 4016.72 | upper bound: 5225.1
# pwXU :  mean: 3581.89 | lower bound: 3111.41 | upper bound: 4052.37
# XDP :  mean: 3581.23 | lower bound: 3113.24 | upper bound: 4049.22
# XUP :  mean: 3858.76 | lower bound: 3162.57 | upper bound: 4554.95
# DSP :  mean: 3285.61 | lower bound: 2910.33 | upper bound: 3660.89
